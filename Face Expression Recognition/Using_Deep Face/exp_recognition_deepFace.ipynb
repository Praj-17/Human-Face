# %% [markdown]
# ## DeepFace Library implementation for expression analysis

# %%
import cv2
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
img  = cv2.imread("E:\CODING PLAYGROUND\CODE\Deep Leaning\Human Face\Gallery\happy.jfif")

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17104/1102709503.py in <module>
# ----> 1 predictions = DeepFace.analyze(img)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     353
#     354         if 'gender' in actions and 'gender' not in built_models:
# --> 355                 models['gender'] = build_model('Gender')
#     356
#     357         if 'race' in actions and 'race' not in built_models:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\deepface\DeepFace.py in build_model(model_name)
#      59                 model = models.get(model_name)
#      60                 if model:
# ---> 61                         model = model()
#      62                         model_obj[model_name] = model
# ...

# %%
predictions
# Out:
# {'emotion': {'angry': 8.49401224269769e-11,
#   'disgust': 3.9087172527779824e-27,
#   'fear': 1.8912255515634724e-15,
#   'happy': 100.0,
#   'sad': 4.334692327301326e-08,
#   'surprise': 3.0002263694262066e-10,
#   'neutral': 1.908734802158474e-09},
#  'dominant_emotion': 'happy',
#  'region': {'x': 79, 'y': 26, 'w': 111, 'h': 111},
#  'age': 23,
#  'gender': 'Man',
#  'race': {'asian': 99.06653165817261,
#   'indian': 0.08689570240676403,
#   'black': 0.0005440377208287828,
#   'white': 0.06724068080075085,
#   'middle eastern': 0.0001410380264132982,
#   'latino hispanic': 0.7786506786942482},
#  'dominant_race': 'asian'}

# %%
img  = cv2.imread("E:\CODING PLAYGROUND\CODE\Deep Leaning\Human Face\Gallery\happy2..jpg")

# %%
DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.43it/s]
# {'emotion': {'angry': 0.0010646231203281786,
#   'disgust': 7.053342718915667e-10,
#   'fear': 85.58539748191833,
#   'happy': 14.07187283039093,
#   'sad': 0.002342024708923418,
#   'surprise': 0.33927648328244686,
#   'neutral': 5.145199111211696e-05},
#  'dominant_emotion': 'fear',
#  'region': {'x': 223, 'y': 77, 'w': 55, 'h': 55},
#  'age': 27,
#  'gender': 'Man',
#  'race': {'asian': 0.6224312259215847,
#   'indian': 0.18515364439211157,
#   'black': 0.02537715341815522,
#   'white': 84.30803920674558,
#   'middle eastern': 4.074334223528756,
#   'latino hispanic': 10.784660922566708},
#  'dominant_race': 'white'}

# %%
img  = cv2.imread("E:\CODING PLAYGROUND\CODE\Deep Leaning\Human Face\Gallery\happy3.jpg")
DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.75it/s]
# {'emotion': {'angry': 7.919172162473842e-06,
#   'disgust': 3.7968652527586855e-09,
#   'fear': 0.00012131213225075044,
#   'happy': 99.11611080169678,
#   'sad': 4.121576751003886e-05,
#   'surprise': 0.0006061651220079511,
#   'neutral': 0.883109774440527},
#  'dominant_emotion': 'happy',
#  'region': {'x': 274, 'y': 74, 'w': 195, 'h': 195},
#  'age': 28,
#  'gender': 'Man',
#  'race': {'asian': 0.034065014035590827,
#   'indian': 0.15011006929636414,
#   'black': 0.01209218752817251,
#   'white': 76.4008984804689,
#   'middle eastern': 6.170074636940637,
#   'latino hispanic': 17.23276032404663},
#  'dominant_race': 'white'}

# %%
img  = cv2.imread("E:\CODING PLAYGROUND\CODE\Deep Leaning\Human Face\Gallery\sad1.jpg")
DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s]
# {'emotion': {'angry': 7.341506024688841,
#   'disgust': 0.0008413825118085191,
#   'fear': 8.003692805987168,
#   'happy': 0.012747088508506924,
#   'sad': 67.99692916851814,
#   'surprise': 0.06821902759002313,
#   'neutral': 16.576063130859325},
#  'dominant_emotion': 'sad',
#  'region': {'x': 506, 'y': 278, 'w': 516, 'h': 516},
#  'age': 31,
#  'gender': 'Man',
#  'race': {'asian': 0.0049336824304191396,
#   'indian': 6.049643829464912,
#   'black': 0.007466929673682898,
#   'white': 7.0457108318805695,
#   'middle eastern': 82.80901908874512,
#   'latino hispanic': 4.083229228854179},
#  'dominant_race': 'middle eastern'}

# %% [markdown]
# ## Implementing the same in real time

# %%
# capture = cv2.VideoCapture(0)
# while True:
#     ret, current_frame = capture.read()
#     # current_frame = cv2.cvtColor(current_frame,cv2.COLOR_BGR2RGB)
#     predictions = DeepFace.analyze(img)
#     face_location = predictions['region']
#     print(face_location)
#     x,y,w,h = face_location.values()
#     cv2.rectangle(current_frame,(x,y),(x+w,y+h),(0,255,0),2)
#     font = cv2.FONT_HERSHEY_DUPLEX
#     cv2.putText(current_frame,predictions['dominant_emotion'],(x,y+10),font,0.5,(25,200,255),1)
#     cv2.imshow("Webcam video", current_frame)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         breakq
# capture.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ### the above method failed hence going for another

# %%
faceCascade = cv2.CascadeClassifier("E:\CODING PLAYGROUND\CODE\Deep Leaning\Human Face\haarcascade_frontalface_default.xml")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_DUPLEX
cv2.putText(img,predictions['dominant_emotion'],(300,500),font,5,(0,0,255),3,cv2.LINE_4)
# Out:
# array([[[124, 132, 139],
#         [124, 132, 139],
#         [124, 132, 139],
#         ...,
#         [171, 173, 174],
#         [171, 170, 172],
#         [170, 169, 173]],
#
#        [[124, 131, 140],
#         [124, 132, 139],
#         [124, 132, 139],
#         ...,
#         [171, 173, 174],
#         [170, 172, 173],
#         [171, 170, 174]],
#
#        [[124, 131, 140],
#         [124, 132, 139],
#         [124, 132, 139],
#         ...,
#         [171, 173, 174],
#         [170, 172, 173],
#         [169, 170, 174]],
#
#        ...,
#
#        [[ 57,  47,  40],
#         [ 57,  47,  40],
#         [ 57,  47,  40],
#         ...,
#         [ 57,  47,  40],
#         [ 57,  47,  40],
#         [ 57,  47,  40]],
#
#        [[ 57,  47,  40],
#         [ 57,  47,  40],
#         [ 57,  47,  40],
#         ...,
#         [ 57,  47,  40],
#         [ 57,  47,  40],
#         [ 57,  47,  40]],
#
#        [[ 57,  47,  40],
#         [ 57,  47,  40],
#         [ 57,  47,  40],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
# import cv2
# from deepface import DeepFace

# faceCascade = cv2.CascadeClassifier("E:\CODING PLAYGROUND\CODE\Deep Leaning\Human Face\haarcascade_frontalface_default.xml")
# capture = cv2.VideoCapture(0)
# # if not capture.isOpened(0):
# #     capture = cv2.VideoCapture(0)
# # if not capture.isOpened():
# #     raise IOError("Cannot open Webcam")
# while True:
#     ret, frame = capture.read()
#     result = DeepFace.analyze(frame,actions=['emotion'])
#     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     faces = faceCascade.detectMultiScale(gray,1.1,4)
#     if faces == ():
#         continue
#     for(x,y,w,h) in faces:
#         cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
#     font =cv2.FONT_HERSHEY_SIMPLEX
#     cv2.putText(frame,
#                 result['dominant_emotion'],
#                 (x,y+10),font, 3, (0,0,255),2,cv2.LINE_4)
#     cv2.imshow("Original Video",frame)
#     if cv2.waitKey(2) & 0xFF == ord('q'):
#         break

# capture.release()
# cv2.destroyAllWindows()

# %%
img  = cv2.imread("2.jpeg")
DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.91it/s]
# {'emotion': {'angry': 1.0845370305798667,
#   'disgust': 0.0011136435868900172,
#   'fear': 1.043035804065216,
#   'happy': 3.8079454039302707,
#   'sad': 8.33332364757798,
#   'surprise': 0.07720659365059994,
#   'neutral': 85.65283928232427},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 347, 'y': 58, 'w': 107, 'h': 107},
#  'age': 27,
#  'gender': 'Man',
#  'race': {'asian': 5.988795570566197e-09,
#   'indian': 9.457628458164891e-07,
#   'black': 100.0,
#   'white': 5.177120007243382e-13,
#   'middle eastern': 2.138861021616905e-12,
#   'latino hispanic': 4.236056505568797e-08},
#  'dominant_race': 'black'}

# %%
img  = cv2.imread("3.jpeg")
DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22168/2612130048.py in <module>
#       1 img  = cv2.imread("3.jpeg")
# ----> 2 DeepFace.analyze(img)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     389                         if action == 'emotion':
#     390                                 emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 391                                 img, region = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     392
# ...
